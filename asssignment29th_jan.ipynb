# %%
# Q1
# Ans. Guido van Rossum

# Q2
# Ans.  Python support three programming paradigms: Imperative, Functional, and Object-Oriented .

# Q3
# Ans. Yes, Python is a case-sensitive language

# Q4
# Ans.   .py

# Q5
# Ans.   Python is an interpreted language

# Q6
# Ans.  a module, a function body, and a class definition

# Q7
# Ans.  ''' my name is pradeep singh narwariya ''' or simplly by writing # this keyword


# Q8
# Ans.  The function sys. version can help us to find the version of python that we are currently working on

# Q9
# Ans.It uses a construct called "lambda" .

# Q10
# Ans.  pip Install Packages

# Q11
# Ans. Function	Description
#         bin()	        Returns the binary version of a number
#         bool()	    Returns the boolean value of the specified object
#         bytearray()	Returns an array of bytes
#         bytes()	    Returns a bytes object 

# Q12  
# Ans.    An identifier can have a maximum length of 79 characters in Python.

# Q13
# Ans.   Libraries help reduce coding errors, make programmers more efficient, and make software smaller in size (and lines of code

# Q14
# Ans.   Memory management in Python involves a private heap containing all Python objects and data structures. 

# Q15
# Ans.     

# Q16
# Ans.   Yes
